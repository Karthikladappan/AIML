# %% [markdown]
# ### The data set has information about features of silhouette extracted from the images of different cars
#
# Four "Corgie" model vehicles were used for the experiment: a double decker bus, Cheverolet van, Saab 9000 and an Opel Manta 400 cars. This particular combination of vehicles was chosen with the expectation that the bus, van and either one of the cars would be readily distinguishable, but it would be more difficult to distinguish between the cars.

# %% [markdown]
# ### 1. Read the dataset using function .dropna() - to avoid dealing with NAs as of now

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt 
vehicle_df=pd.read_csv("vehicle.csv")
from sklearn.cluster import KMeans

# %%
vehicle_df.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# ...

# %%
vehicle_df.isnull().values.any()
# Out:
# True

# %%
vehicle_df.isnull().sum()
# Out:
# compactness                    0
# circularity                    5
# distance_circularity           4
# radius_ratio                   6
# pr.axis_aspect_ratio           2
# max.length_aspect_ratio        0
# scatter_ratio                  1
# elongatedness                  1
# pr.axis_rectangularity         3
# max.length_rectangularity      0
# scaled_variance                3
# scaled_variance.1              2
# scaled_radius_of_gyration      2
# scaled_radius_of_gyration.1    4
# skewness_about                 6
# skewness_about.1               1
# skewness_about.2               1
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
vehicle_df.shape
# Out:
# (846, 19)

# %%
 vehicle_df.dropna(inplace=True)

# %%
vehicle_df.isnull().sum()
# Out:
# compactness                    0
# circularity                    0
# distance_circularity           0
# radius_ratio                   0
# pr.axis_aspect_ratio           0
# max.length_aspect_ratio        0
# scatter_ratio                  0
# elongatedness                  0
# pr.axis_rectangularity         0
# max.length_rectangularity      0
# scaled_variance                0
# scaled_variance.1              0
# scaled_radius_of_gyration      0
# scaled_radius_of_gyration.1    0
# skewness_about                 0
# skewness_about.1               0
# skewness_about.2               0
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
vehicle_df.shape
# Out:
# (813, 19)

# %% [markdown]
# ### 2. Print/ Plot the dependent (categorical variable) - Class column

# %% [markdown]
# Since the variable is categorical, you can use value_counts function

# %%
vehicle_df["class"].value_counts().index.tolist()
# Out:
# ['car', 'bus', 'van']

# %% [markdown]
# ### Check for any missing values in the data

# %%
null_data = vehicle_df[vehicle_df.isnull().any(axis=1)]

# %%
null_data
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# ### 3. Standardize the data

# %%
data = vehicle_df 
concat_data=pd.DataFrame
       
def standardize(group):
    median, std = group.median(), group.std()  #Get the median and the standard deviation of every group 
    outliers = (group - median).abs() > 2*std # Subtract median from every member of each group. Take absolute values > 2std
    group[outliers] = group.median()       
    return group

# %%
# iterate each column to standardize
for column in data.columns:
    data_corrected = (data.groupby(column).transform(standardize)) 
    concat_data = data_corrected.join(pd.DataFrame(vehicle_df[column]))
# Out:
# C:\Users\Karthikeyan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Karthikeyan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Karthikeyan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %%
vehicle_df.columns
# Out:
# Index(['compactness', 'circularity', 'distance_circularity', 'radius_ratio',
#        'pr.axis_aspect_ratio', 'max.length_aspect_ratio', 'scatter_ratio',
#        'elongatedness', 'pr.axis_rectangularity', 'max.length_rectangularity',
#        'scaled_variance', 'scaled_variance.1', 'scaled_radius_of_gyration',
#        'scaled_radius_of_gyration.1', 'skewness_about', 'skewness_about.1',
#        'skewness_about.2', 'hollows_ratio', 'class'],
#       dtype='object')

# %%
concat_data.head(10)
# Out:
#     compactness  circularity  distance_circularity  radius_ratio  \
# 0            95         48.0                  83.0         178.0
# 1            91         41.0                  84.0         141.0
# 2           104         50.0                 106.0         209.0
# 3            93         41.0                  82.0         159.0
# 4            85         44.0                  70.0         205.0
# 6            97         43.0                  73.0         173.0
# 7            90         43.0                  66.0         157.0
# 8            86         34.0                  62.0         140.0
# 10           86         36.0                  70.0         143.0
# 11           90         34.0                  66.0         136.0
#
#     pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                   72.0                       10          162.0
# 1                   57.0                        9          149.0
# ...

# %%
vehicle_df.dtypes
# Out:
# compactness                      int64
# circularity                    float64
# distance_circularity           float64
# radius_ratio                   float64
# pr.axis_aspect_ratio           float64
# max.length_aspect_ratio          int64
# scatter_ratio                  float64
# elongatedness                  float64
# pr.axis_rectangularity         float64
# max.length_rectangularity        int64
# scaled_variance                float64
# scaled_variance.1              float64
# scaled_radius_of_gyration      float64
# scaled_radius_of_gyration.1    float64
# skewness_about                 float64
# skewness_about.1               float64
# skewness_about.2               float64
# hollows_ratio                    int64
# class                           object
# dtype: object

# %% [markdown]
# Since the dimensions of the data are not really known to us, it would be wise to standardize the data using z scores before we go for any clustering methods.
# You can use zscore function to do this

# %%
from scipy.stats import zscore

# %%
vehicle_df_z=vehicle_df.drop('class',axis=1)

# %%
vehicle_df_z.apply(zscore)
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 0       0.163231     0.520408              0.060669      0.264970
# 1      -0.322874    -0.619123              0.124067     -0.836393
# 2       1.256966     0.845988              1.518823      1.187734
# 3      -0.079822    -0.619123             -0.002729     -0.300595
# 4      -1.052030    -0.130753             -0.763506      1.068668
# 6       0.406283    -0.293543             -0.573312      0.116137
# 7      -0.444400    -0.293543             -1.017098     -0.360128
# 8      -0.930504    -1.758654             -1.270690     -0.866160
# 10     -0.930504    -1.433074             -0.763506     -0.776860
# 11     -0.444400    -1.758654             -1.017098     -0.985226
# 12     -0.687452     0.194828             -0.509914      0.056604
# 13     -0.565926    -0.456333              0.187465     -0.747094
# 14      0.041705     0.683198             -0.192923      1.009135
# ...

# %% [markdown]
# ### K - Means Clustering

# %% [markdown]
# ### 4. Assign a dummy array called distortion

# %%
meanDistortions=np.array

# %% [markdown]
# You can later use this array to plot the elbow plot

# %% [markdown]
# ### 5. Calculating distortion - C distance

# %%
from scipy.spatial.distance import cdist
clusters=range(1,10)
meanDistortions=[]

for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(vehicle_df_z)
    prediction=model.predict(vehicle_df_z)
    meanDistortions.append(sum(np.min(cdist(vehicle_df_z, model.cluster_centers_, 'euclidean'), axis=1)) / vehicle_df_z.shape[0])


plt.plot(clusters, meanDistortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Average distortion')
plt.title('Selecting k with the Elbow Method')
# Out:
# Text(0.5,1,'Selecting k with the Elbow Method')

# %% [markdown]
# Iterating values of k from 1 to 10 fit K means model
# Using c distance - Get the measure for Sum of squares error.

# %% [markdown]
# ### 6. Plotting Elbow/ Scree Plot

# %% [markdown]
# Use Matplotlib to plot the scree plot - Note: Scree plot plots distortion vs the no of clusters

# %% [markdown]
# ### Find out the optimal value of K

# %% [markdown]
# ### Using optimal value of K - Cluster the data.
# Note: Since the data has more than 2 dimension we cannot visualize the data. As an alternative, we can observe the centroids and note how they are distributed across different dimensions

# %%
centroids = model.cluster_centers_



# Comparing with scikit-learn centroids

print("Centroid values")


print("sklearn")

print(centroids) # From sci-kit learn
# Out:
# Centroid values
# sklearn
# [[104.21428571  53.65873016 102.86507937 202.28571429  62.43650794
#    10.55555556 217.58730159  30.65079365  24.44444444 169.45238095
#   227.22222222 699.37301587 212.29365079  71.81746032   7.58730159
#    16.34126984 187.88888889 197.58730159]
#  [ 87.35428571  44.42285714  74.88       143.88571429  59.96571429
#     8.21714286 152.61714286  44.16571429  19.24571429 148.21142857
#   172.85714286 342.80571429 176.15428571  76.54857143   5.82285714
#     9.18285714 184.23428571 190.69142857]
#  [ 95.91549296  45.56338028  90.69014085 195.63380282  64.15492958
#     8.32394366 182.23943662  35.98591549  21.46478873 147.76056338
#   203.1971831  501.42253521 177.74647887  67.95774648   6.11267606
#    13.4084507  193.50704225 200.25352113]
#  [ 87.59016393  37.85245902  61.3442623  128.49180328  56.3852459
#     6.3442623  127.28688525  52.99180328  17.66393443 132.17213115
#   148.12295082 239.45081967 139.42622951  73.68032787   6.77868852
# ...

# %% [markdown]
# You can use kmeans.cluster_centers_ function to pull the centroid information from the instance

# %% [markdown]
# ### 7. Store the centroids in a dataframe with column names from the original dataset given

# %% [markdown]
# Hint: Use pd.Dataframe function

# %% [markdown]
# ### Use kmeans.labels_ function to print out the labels of the classes
